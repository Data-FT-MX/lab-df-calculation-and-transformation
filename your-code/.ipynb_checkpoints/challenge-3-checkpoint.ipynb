# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders.csv` data set in the previous [Subsetting and Descriptive Stats lab](../../lab-subsetting-and-descriptive-stats/your-code/main.ipynb). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# # Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders.csv` from the "subsetting" lab folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# enter your code here
orders = pd.read_csv("Orders.csv")
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here
amount_per_client = orders.groupby('CustomerID').sum('amount_spent')
amount_per_client['amount_spent'].describe(percentiles=[x/100 for x in range(0,100,5)])
# Out:
# count      4339.000000
# mean       2053.793018
# std        8988.248381
# min           0.000000
# 0%            0.000000
# 5%          112.245000
# 10%         156.566000
# 15%         200.154000
# 20%         250.106000
# 25%         307.245000
# 30%         351.658000
# 35%         411.551000
# 40%         489.724000
# 45%         585.844000
# 50%         674.450000
# 55%         786.272000
# 60%         941.942000
# 65%        1119.665000
# 70%        1353.740000
# 75%        1661.640000
# 80%        2057.914000
# 85%        2639.009000
# 90%        3646.164000
# 95%        5840.182000
# max      280206.020000
# Name: amount_spent, dtype: float64

# %%
id_vip = amount_per_client[amount_per_client['amount_spent']>= 5840.18].index
id_vip
# Out:
# Int64Index([12346, 12357, 12359, 12409, 12415, 12428, 12431, 12433, 12435,
#             12451,
#             ...
#             17865, 17949, 18055, 18092, 18102, 18109, 18139, 18172, 18223,
#             18229],
#            dtype='int64', name='CustomerID', length=217)

# %%
id_preferred = amount_per_client[(amount_per_client['amount_spent']<= 5840.18)
                                    & (amount_per_client['amount_spent']>= 1661.64)].index
id_preferred
# Out:
# Int64Index([12347, 12348, 12349, 12352, 12356, 12360, 12362, 12370, 12371,
#             12378,
#             ...
#             18241, 18242, 18245, 18251, 18257, 18259, 18260, 18272, 18283,
#             18287],
#            dtype='int64', name='CustomerID', length=868)

# %%
label = []
for x in orders['CustomerID']:
    if x in id_vip:
        label.append('VIP')
    elif x in id_preferred:
        label.append('Preferred')
    else:
        label.append('NA')
# Out:
# ['Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'VIP',
#  'NA',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'NA',
#  'Preferred',
#  'Preferred',
#  'Preferred',
#  'Preferred',
# ...

# %%
orders['label'] = label
orders.tail()
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                             Description  Quantity          InvoiceDate  \
# 397919      pack of 20 spaceboy napkins        12  2011-12-09 12:50:00
# 397920     children's apron dolly girl          6  2011-12-09 12:50:00
# 397921    childrens cutlery dolly girl          4  2011-12-09 12:50:00
# 397922  childrens cutlery circus parade         4  2011-12-09 12:50:00
# 397923    baking set 9 piece retrospot          3  2011-12-09 12:50:00
#
#         UnitPrice  CustomerID Country  amount_spent label
# 397919       0.85       12680  France         10.20    NA
# ...

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# # Q2: How to identify which country has the most VIP Customers?
#
# # Q3: How to identify which country has the most VIP+Preferred Customers combined?
#
# Provide your solution for Q2 below:

# %%
# your code here
#orders[orders['label']=='Preferred']
#orders.groupby(['label','Country']).count()['CustomerID']
orders[orders['label']=='VIP'].groupby(['CustomerID','Country']).size().groupby(['Country']).size().sort_values(ascending=False).head(1)
#orders[orders['label']=='Preferred'].groupby(['Country','label'])['CustomerID'].count().head(1)
#orders[orders['label']=='Preferred'].groupby(['CustomerID','Country']).size().groupby(['Country']).size().sort_values(ascending=False)
# Out:
# Country
# United Kingdom    177
# dtype: int64

# %%
orders[orders['label']!='NA'].groupby(['CustomerID','Country']).size().groupby(['Country']).size().sort_values(ascending=False).head(1)
# Out:
# Country
# United Kingdom    932
# dtype: int64

# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders.csv` data set in the previous [Subsetting and Descriptive Stats lab](../../lab-subsetting-and-descriptive-stats/your-code/main.ipynb). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# # Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders.csv` from the "subsetting" lab folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# enter your code here
orders = pd.read_csv("Orders.csv")
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00
# 3       3.39       17850  United Kingdom         20.34
# 4       3.39       17850  United Kingdom         20.34

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here
# Obtaining a list of unique values for Customer ID to check unique values lenght
Customer_ID = list(pd.unique(orders['CustomerID']))
len(Customer_ID)
# Out:
# 4339

# %%
# Sub Problem 1

# %%
spendings_by_customer = orders.loc[:,['CustomerID','amount_spent']].groupby('CustomerID').sum()
spendings_by_customer
# rows in unique_customer_spendings is the same lenght as Customer_ID list
# Out:
#             amount_spent
# CustomerID
# 12346           77183.60
# 12347            4310.00
# 12348            1797.24
# 12349            1757.55
# 12350             334.40
# ...                  ...
# 18280             180.60
# 18281              80.82
# 18282             178.05
# 18283            2094.88
# 18287            1837.28
#
# [4339 rows x 1 columns]

# %%
# Sub Problem 2

# %%
# Apply ordrs.describe() to check quantiles amounts in amount_spent column
orders.describe()
# quartile 75% is much lower than max, let's check how is amount spent behaving
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# 25%         2.000000      11.000000       2.000000       1.250000
# 50%         3.000000      13.000000       6.000000       1.950000
# 75%         5.000000      14.000000      12.000000       3.750000
# max         7.000000      20.000000   80995.000000    8142.750000
#
#           CustomerID   amount_spent
# count  397924.000000  397924.000000
# mean    15294.315171      22.394749
# std      1713.169877     309.055588
# min     12346.000000       0.000000
# 25%     13969.000000       4.680000
# 50%     15159.000000      11.800000
# 75%     16795.000000      19.800000
# max     18287.000000  168469.600000

# %%
spendings_by_customer.sort_values('amount_spent', ascending=False)
# Out:
#             amount_spent
# CustomerID
# 14646          280206.02
# 18102          259657.30
# 17450          194550.79
# 16446          168472.50
# 14911          143825.06
# ...                  ...
# 17956              12.75
# 16454               6.90
# 14792               6.20
# 16738               3.75
# 13256               0.00
#
# [4339 rows x 1 columns]

# %%
spendings_by_customer["amount_spent"].plot.box();
# box graphic shows 75% of data is fewer than a thousand spent money units

# %%
# obtaining quantiles
# example: df['English'].quantile(q=0.9)
q95 = spendings_by_customer['amount_spent'].quantile(q=0.95)
q95
# Out:
# 5840.181999999982

# %%
q75 = spendings_by_customer['amount_spent'].quantile(q=0.75)
q75
# Out:
# 1661.64

# %%
# obtaining VIP clients view in dataframe (clients who have spent equal 
# or higher amount than that of the q95)
VIP_customers_df = spendings_by_customer[spendings_by_customer.loc[:,'amount_spent'] >= q95].sort_values('amount_spent',ascending=False)
VIP_customers_df
# Out:
#             amount_spent
# CustomerID
# 14646          280206.02
# 18102          259657.30
# 17450          194550.79
# 16446          168472.50
# 14911          143825.06
# ...                  ...
# 14505            5905.64
# 14415            5900.28
# 14944            5900.25
# 13209            5891.61
# 13534            5870.08
#
# [217 rows x 1 columns]

# %%
VIP_customers = VIP_customers_df.index.values.tolist()
print(VIP_customers)
# Out:
# [14646, 18102, 17450, 16446, 14911, 12415, 14156, 17511, 16029, 12346, 16684, 14096, 13694, 15311, 13089, 17949, 15769, 15061, 14298, 14088, 15749, 12931, 17841, 15098, 13798, 16013, 16422, 12748, 15838, 17404, 17389, 13098, 14680, 13081, 13408, 17857, 16333, 13777, 12753, 12744, 16210, 17675, 17381, 15039, 12471, 12731, 15159, 12901, 12678, 14031, 17428, 13767, 13881, 16839, 12921, 14607, 15856, 17677, 15189, 14051, 15513, 16133, 14866, 16705, 12681, 12621, 12540, 12433, 15498, 12477, 17735, 16525, 14258, 13078, 12536, 15640, 16000, 17340, 12682, 13113, 14606, 12557, 12939, 15125, 14194, 12971, 14895, 12409, 15482, 17581, 13319, 17107, 13340, 14769, 17139, 16779, 17865, 17706, 15251, 14062, 15615, 15502, 16180, 16843, 12590, 13001, 13199, 15078, 12709, 13458, 14733, 16523, 12567, 14367, 14667, 18092, 13969, 12451, 13488, 13090, 16033, 17017, 17243, 17306, 16656, 14527, 12683, 18139, 15358, 16558, 14056, 14936, 16672, 13854, 14952, 18109, 14796, 12428, 15290, 14849, 12757, 17811, 13093, 12435, 13629, 15044, 15194, 18172, 13263, 12474, 12980, 15465, 17396, 12583, 13018, 18229, 16923, 16729, 16745, 16873, 13324, 13985, 14961, 12766, 12798, 12989, 16713, 13027, 16187, 17416, 12705, 12476, 12830, 15023, 18055, 15601, 16652, 16532, 13576, 16746, 15249, 16353, 17338, 12626, 16182, 15144, 12472, 16814, 12431, 18223, 15694, 13225, 13102, 13871, 12359, 13668, 13709, 15005, 17315, 16126, 14057, 12357, 14060, 13418, 17509, 15939, 14735, 12637, 13097, 13316, 14101, 15382, 14505, 14415, 14944, 13209, 13534]

# %%
Preferred_customers_df = spendings_by_customer[spendings_by_customer.loc[:,'amount_spent'].apply(lambda x: q75 <= x <= q95)].sort_values('amount_spent',ascending=False)
Preferred_customers_df
# spendings_by_customer[spendings_by_customer.loc[:,'amount_spent'].apply(lambda x: q75 <= x <= q95)]
# Out:
#             amount_spent
# CustomerID
# 13050            5836.86
# 12720            5781.73
# 15218            5756.89
# 17686            5739.46
# 13178            5725.47
# ...                  ...
# 17656            1674.69
# 16115            1667.97
# 12912            1662.30
# 12530            1662.28
# 13012            1661.84
#
# [868 rows x 1 columns]

# %%
Preferred_customers = Preferred_customers_df.index.values.tolist()
print(Preferred_customers)
# Out:
# [13050, 12720, 15218, 17686, 13178, 16553, 13468, 14110, 14049, 17049, 17716, 13004, 18118, 14688, 17757, 12481, 12839, 16767, 16161, 12539, 15805, 18225, 16609, 16985, 16265, 18198, 12490, 17809, 16701, 17719, 17850, 16303, 13269, 15150, 17730, 17061, 18226, 12362, 15046, 16258, 13756, 16191, 15727, 17858, 13599, 15903, 13941, 17602, 16700, 14562, 15301, 13139, 12432, 15719, 17426, 14329, 14755, 12444, 15032, 15547, 12437, 12700, 15786, 14709, 17133, 12664, 12688, 14292, 17652, 15738, 13013, 15555, 17365, 15298, 15187, 17690, 12955, 14180, 15152, 16722, 12714, 14159, 14135, 14191, 15291, 14189, 14390, 14286, 16931, 13802, 15093, 14004, 17613, 17068, 12484, 13267, 15299, 17975, 12524, 14426, 16984, 17364, 12627, 14085, 14534, 13069, 15955, 16626, 15874, 12712, 13505, 12752, 16945, 14016, 14800, 14525, 17567, 18251, 12347, 15034, 17937, 14422, 12500, 17419, 14277, 15804, 17920, 15971, 12747, 14146, 18041, 12949, 15570, 16549, 13384, 13555, 13988, 15514, 12569, 16592, 17940, 17377, 16401, 16670, 12749, 14092, 12449, 18087, 14401, 12656, 12867, 13815, 12841, 12957, 12378, 14547, 16186, 17769, 15529, 17001, 15416, 17611, 12779, 12727, 14299, 13523, 13183, 17651, 12473, 17593, 14739, 13999, 14291, 18073, 13124, 15195, 16717, 12662, 16327, 13266, 17091, 15867, 12755, 12597, 13435, 12668, 16145, 16655, 16168, 16019, 12562, 17173, 16904, 12429, 17238, 14145, 13552, 16570, 15808, 14282, 12502, 12647, 13680, 16240, 14364, 15845, 15622, 13148, 17819, 15379, 12553, 16253, 15581, 15296, 18079, 13137, 12417, 16712, 13426, 12619, 16440, 13381, 17230, 14543, 17528, 13327, 13520, 17576, 14040, 13082, 15505, 15113, 16242, 15484, 14132, 17203, 17491, 15544, 12370, 14503, 13448, 13334, 12454, 17160, 13953, 16360, 14395, 16131, 14907, 16458, 13993, 13014, 17758, 15410, 13536, 15129, 15974, 17725, 15676, 14221, 12406, 15981, 13437, 17669, 13198, 15228, 13842, 15708, 16011, 14227, 16818, 16607, 17183, 13015, 12643, 12613, 12594, 16556, 13373, 14841, 14702, 15632, 12480, 15764, 17723, 13952, 13047, 15443, 17050, 14175, 13880, 13268, 14388, 16107, 17220, 13868, 17685, 13758, 14844, 12456, 17672, 17231, 16837, 16041, 15861, 17863, 15065, 14235, 13742, 16156, 13685, 16326, 16678, 13869, 14099, 16905, 15491, 14257, 14565, 13135, 17059, 13362, 15998, 16218, 18272, 12910, 13631, 16686, 14456, 17799, 16940, 16393, 16709, 12598, 12395, 18094, 12754, 12916, 15521, 17659, 17504, 12670, 14307, 15687, 14639, 13451, 14032, 15854, 16497, 17924, 14868, 17084, 17444, 16316, 14530, 17512, 15606, 12906, 14112, 12438, 17644, 18144, 12408, 13735, 16633, 15673, 14251, 17728, 14005, 15628, 14711, 13901, 14535, 12685, 18145, 16928, 15984, 14852, 14572, 17596, 14842, 13174, 16871, 12356, 14903, 18230, 13230, 16081, 16764, 15993, 13769, 12578, 12758, 17739, 14626, 17213, 12388, 14121, 17838, 13870, 15356, 15114, 14854, 13971, 15321, 12669, 14808, 14125, 15696, 16938, 16003, 12840, 12380, 12708, 15796, 17069, 13285, 13654, 14107, 14732, 18097, 17386, 12625, 17346, 13883, 14713, 12360, 14439, 15671, 12721, 13851, 16618, 18260, 13658, 17655, 15752, 13804, 13771, 12520, 17402, 18077, 13422, 13644, 17965, 18210, 16255, 14262, 13021, 15782, 14397, 12836, 18075, 12726, 16241, 13136, 14408, 13983, 17317, 12600, 16919, 13895, 14243, 15033, 13911, 14546, 16912, 15485, 18245, 16308, 15572, 14334, 14701, 14676, 13344, 14776, 17700, 13471, 14659, 17314, 13975, 17449, 13394, 15245, 15271, 12352, 13695, 12517, 15932, 16477, 12483, 12913, 16710, 14315, 13507, 13588, 17682, 17188, 14766, 14502, 17164, 12455, 15750, 17131, 13784, 15674, 14163, 15527, 17071, 13949, 16143, 17722, 15089, 15373, 12397, 17589, 15980, 18065, 13141, 15370, 17530, 14493, 14554, 14239, 15270, 13722, 17434, 14930, 13908, 15755, 12457, 17634, 14030, 14440, 15140, 14309, 12704, 18259, 12584, 18257, 17954, 15281, 12782, 15785, 17313, 17744, 17211, 14290, 15365, 13994, 13704, 15288, 16735, 16550, 15105, 13115, 15704, 12615, 13527, 17696, 12684, 16782, 13317, 17768, 14466, 13700, 16057, 16209, 14432, 16293, 17442, 15235, 16 ...

# %%
# Labeling the customers in original dataframe
orders['Customer_group'] = np.where(orders['CustomerID'].isin(VIP_customers),
                                   'VIP Customer',
                                   np.where(orders['CustomerID'].isin(Preferred_customers),
                                   'Preferred Customer',
                                   'Regular Customer'))

orders.head(50)
# Out:
#     Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0            0     536365    85123A  2010     12    3     8
# 1            1     536365     71053  2010     12    3     8
# 2            2     536365    84406B  2010     12    3     8
# 3            3     536365    84029G  2010     12    3     8
# 4            4     536365    84029E  2010     12    3     8
# 5            5     536365     22752  2010     12    3     8
# 6            6     536365     21730  2010     12    3     8
# 7            7     536366     22633  2010     12    3     8
# 8            8     536366     22632  2010     12    3     8
# 9            9     536367     84879  2010     12    3     8
# 10          10     536367     22745  2010     12    3     8
# 11          11     536367     22748  2010     12    3     8
# 12          12     536367     22749  2010     12    3     8
# 13          13     536367     22310  2010     12    3     8
# 14          14     536367     84969  2010     12    3     8
# 15          15     536367     22623  2010     12    3     8
# 16          16     536367     22622  2010     12    3     8
# 17          17     536367     21754  2010     12    3     8
# 18          18     536367     21755  2010     12    3     8
# 19          19     536367     21777  2010     12    3     8
# 20          20     536367     48187  2010     12    3     8
# 21          21     536368     22960  2010     12    3     8
# 22          22     536368     22913  2010     12    3     8
# 23          23     536368     22912  2010     12    3     8
# 24          24     536368     22914  2010     12    3     8
# 25          25     536369     21756  2010     12    3     8
# 26          26     536370     22728  2010     12    3     8
# 27          27     536370     22727  2010     12    3     8
# 28          28     536370     22726  2010     12    3     8
# 29          29     536370     21724  2010     12    3     8
# 30          30     536370     21883  2010     12    3     8
# 31          31     536370     10002  2010     12    3     8
# 32          32     536370     21791  2010     12    3     8
# 33          33     536370     21035  2010     12    3     8
# 34          34     536370     22326  2010     12    3     8
# 35          35     536370     22629  2010     12    3     8
# 36          36     536370     22659  2010     12    3     8
# 37          37     536370     22631  2010     12    3     8
# 38          38     536370     22661  2010     12    3     8
# 39          39     536370     21731  2010     12    3     8
# 40          40     536370     22900  2010     12    3     8
# 41          41     536370     21913  2010     12    3     8
# 42          42     536370     22540  2010     12    3     8
# 43          43     536370     22544  2010     12    3     8
# 44          44     536370     22492  2010     12    3     8
# 45          45     536370      POST  2010     12    3     8
# 46          46     536371     22086  2010     12    3     9
# 47          47     536372     22632  2010     12    3     9
# 48          48     536372     22633  2010     12    3     9
# 49          49     536373    85123A  2010     12    3     9
#
#                             Description  Quantity          InvoiceDate  \
# 0    white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                   white metal lantern         6  2010-12-01 08:26:00
# 2        cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3   knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4        red woolly hottie white heart.         6  2010-12-01 08:26:00
# 5          set 7 babushka nesting boxes         2  2010-12-01 08:26:00
# 6     glass star frosted t-light holder         6  2010-12-01 08:26:00
# 7                hand warmer union jack         6  2010-12-01 08:28:00
# 8             hand warmer red polka dot         6  2010-12-01 08:28:00
# 9         assorted colour bird ornament        32  2010-12-01 08:34:00
# 10           poppy's playhouse bedroom          6  2010-12-01 08:34:00
# 11            poppy's playhouse kitchen         6  2010-12-01 08:34:00
# 12    feltcraft princess charlotte doll         8  2010-12-01 08:34:00
# 13              ivory knitted mug cosy          6  2010-12-01 08:34:00
# 14   box of 6 assorted colour teaspoons         6  2010-12-01 08:34:00
# 15        box of vintage jigsaw blocks          3  2010-12-01 08:34:00
# 16       box of vintage alphabet blocks         2  2010-12-01 08:34:00
# 17             home building block word         3  2010-12-01 08:34:00
# 18             love building block word         3  2010-12-01 08:34:00
# 19          recipe box with metal heart         4  2010-12-01 08:34:00
# 20                  doormat new england         4  2010-12-01 08:34:00
# 21             jam making set with jars         6  2010-12-01 08:34:00
# 22          red coat rack paris fashion         3  2010-12-01 08:34:00
# 23       yellow coat rack paris fashion         3  2010-12-01 08:34:00
# 24         blue coat rack paris fashion         3  2010-12-01 08:34:00
# 25             bath building block word         3  2010-12-01 08:35:00
# 26            alarm clock bakelike pink        24  2010-12-01 08:45:00
# 27            alarm clock bakelike red         24  2010-12-01 08:45:00
# 28           alarm clock bakelike green        12  2010-12-01 08:45:00
# 29      panda and bunnies sticker sheet        12  2010-12-01 08:45:00
# 30                     stars gift tape         24  2010-12-01 08:45:00
# 31          inflatable political globe         48  2010-12-01 08:45:00
# 32   vintage heads and tails card game         24  2010-12-01 08:45:00
# 33      set/2 red retrospot tea towels         18  2010-12-01 08:45:00
# 34  round snack boxes set of4 woodland         24  2010-12-01 08:45:00
# 35                  spaceboy lunch box         24  2010-12-01 08:45:00
# 36              lunch box i love london        24  2010-12-01 08:45:00
# 37             circus parade lunch box         24  2010-12-01 08:45:00
# 38      charlotte bag dolly girl design        20  2010-12-01 08:45:00
# 39        red toadstool led night light        24  2010-12-01 08:45:00
# 40      set 2 tea towels i love london         24  2010-12-01 08:45:00
# 41       vintage seaside jigsaw puzzles        12  2010-12-01 08:45:00
# 42           mini jigsaw circus parade         24  2010-12-01 08:45:00
# 43                 mini jigsaw spaceboy        24  2010-12-01 08:45:00
# 44              mini paint set vintage         36  2010-12-01 08:45:00
# 45                              postage         3  2010-12-01 08:45:00
# 46      paper chain kit 50's christmas         80  2010-12-01 09:00:00
# 47            hand warmer red polka dot         6  2010-12-01 09:01:00
# 48               hand warmer union jack         6  2010-12-01 09:01:00
# 49   white hanging heart t-light holder         6  2010-12-01 09:02:00
#
#     UnitPrice  CustomerID         Country  amount_spent      Customer_group
# 0        2.55       17850  United Kingdom         15.30  Preferred Customer
# 1        3.39       17850  United Kingdom         20.34  Preferred Customer
# 2        2.75       17850  United Kingdom         22.00  Preferred Customer
# 3        3.39       17850  United Kingdom         20.34  Preferred Customer
# 4        3.39       17850  United Kingdom         20.34  Preferred Customer
# 5        7.65       17850  United Kingdom         15.30  Preferred Customer
# 6        4.25       17850  United Kingdom         25.50  Preferred Customer
# 7        1.85       17850  United Kingdom         11.10  Preferred Customer
# 8        1.85       17850  United Kingdom         11.10  Preferred Customer
# 9        1.69       13047  United Kingdom         54.08  Preferred Customer
# 10       2.10       13047  United Kingdom         12.60  Preferred Customer
# 11       2.10       13047  United Kingdom         12.60  Preferred Customer
# 12       3.75       13047  United Kingdom         30.00  Preferred Customer
# 13       1.65       13047  United Kingdom          9.90  Preferred Customer
# 14       4.25       13047  United Kingdom         25.50  Preferred Customer
# 15       4.95       13047  United Kingdom         14.85  Preferred Customer
# 16       9.95       13047  United Kingdom         19.90  Preferred Customer
# 17       5.95       13047  United Kingdom         17.85  Preferred Customer
# 18       5.95       13047  United Kingdom         17.85  Preferred Customer
# 19       7.95       13047  United Kingdom         31.80  Preferred Customer
# 20       7.95       13047  United Kingdom         31.80  Preferred Customer
# 21       4.25       13047  United Kingdom         25.50  Preferred Customer
# 22       4.95       13047  United Kingdom         14.85  Preferred Customer
# 23       4.95       13047  United Kingdom         14.85  Preferred Customer
# 24       4.95       13047  United Kingdom         14.85  Preferred Customer
# 25       5.95       13047  United Kingdom         17.85  Preferred Customer
# 26       3.75       12583          France         90.00        VIP Customer
# 27       3.75       12583          France         90.00        VIP Customer
# 28       3.75       12583          France         45.00        VIP Customer
# 29       0.85       12583          France         10.20        VIP Customer
# 30       0.65       12583          France         15.60        VIP Customer
# 31       0.85       12583          France         40.80        VIP Customer
# 32       1.25       12583          France         30.00        VIP Customer
# 33       2.95       12583          France         53.10        VIP Customer
# 34       2.95       12583          France         70.80        VIP Customer
# 35       1.95       12583          France         46.80        VIP Customer
# 36       1.95       12583          France         46.80        VIP Customer
# 37       1.95       12583          France         46.80        VIP Customer
# 38       0.85       12583          France         17.00        VIP Customer
# 39       1.65       12583          France         39.60        VIP Customer
# 40       2.95       12583          France         70.80        VIP Customer
# 41       3.75       12583          France         45.00        VIP Customer
# 42       0.42       12583          France         10.08        VIP Customer
# 43       0.42       12583          France         10.08        VIP Customer
# 44       0.65       12583          France         23.40        VIP Customer
# 45      18.00       12583          France         54.00        VIP Customer
# 46       2.55       13748  United Kingdom        204.00    Regular Customer
# 47       1.85       17850  United Kingdom         11.10  Preferred Customer
# 48       1.85       17850  United Kingdom         11.10  Preferred Customer
# 49       2.55       17850  United Kingdom         15.30  Preferred Customer

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# # Q2: How to identify which country has the most VIP Customers?
#
# # Q3: How to identify which country has the most VIP+Preferred Customers combined?
#
# Provide your solution for Q2 below:

# %% [markdown]
# ### Q2: How to identify which country has the most VIP Customers?

# %%
# your code here
#orders.loc[:,['CustomerID','Country','Customer_group']].groupby(['CustomerID','Country','Customer_group'], as_index=False)
a = orders[['CustomerID','Country']][orders['Customer_group'] == 'VIP Customer'].groupby(['CustomerID','Country'],as_index=False).count()
b = a.groupby('Country').count().sort_values('CustomerID',ascending=False)
b
# Answer should be United Kingdom with 117 VIP clients
# To verify this, I'll aproximate the problem with another method
# Out:
#                  CustomerID
# Country
# United Kingdom          177
# Germany                  10
# France                    9
# Switzerland               3
# Spain                     2
# Portugal                  2
# Australia                 2
# EIRE                      2
# Japan                     2
# Finland                   1
# Belgium                   1
# Netherlands               1
# Norway                    1
# Denmark                   1
# Singapore                 1
# Cyprus                    1
# Sweden                    1
# Channel Islands           1

# %%
# Creating new column 'CustomerType-Country'
orders['CustomerType-Country'] = orders['Country'] + '-' + orders['Customer_group']

# %%
VIP = orders[['CustomerID','CustomerType-Country']][orders['Customer_group'] == 'VIP Customer'].groupby(['CustomerID','CustomerType-Country'],as_index=False).count()
VIP.groupby('CustomerType-Country').count().sort_values('CustomerID',ascending=False)
# I get the same result United Kingdom with 117 VIP Customers
# Out:
#                               CustomerID
# CustomerType-Country
# United Kingdom-VIP Customer          177
# Germany-VIP Customer                  10
# France-VIP Customer                    9
# Switzerland-VIP Customer               3
# Spain-VIP Customer                     2
# Portugal-VIP Customer                  2
# Australia-VIP Customer                 2
# EIRE-VIP Customer                      2
# Japan-VIP Customer                     2
# Finland-VIP Customer                   1
# Belgium-VIP Customer                   1
# Netherlands-VIP Customer               1
# Norway-VIP Customer                    1
# Denmark-VIP Customer                   1
# Singapore-VIP Customer                 1
# Cyprus-VIP Customer                    1
# Sweden-VIP Customer                    1
# Channel Islands-VIP Customer           1

# %% [markdown]
# ### Q3: How to identify which country has the most VIP+Preferred Customers combined?

# %%
a = orders[['CustomerID','Country']][(orders['Customer_group'] == 'Preferred Customer') & (orders['Customer_group'] == 'Preferred Customer')].groupby(['CustomerID','Country'],as_index=False).count()
b = a.groupby('Country').count().sort_values('CustomerID',ascending=False)
b
# Out:
#                  CustomerID
# Country
# United Kingdom          755
# Germany                  29
# France                   20
# Belgium                  11
# Spain                     7
# Switzerland               6
# Norway                    6
# Italy                     5
# Portugal                  5
# Finland                   4
# Channel Islands           3
# Cyprus                    3
# Austria                   3
# Japan                     2
# Australia                 2
# Israel                    2
# Denmark                   2
# Lebanon                   1
# Malta                     1
# Greece                    1
# Poland                    1
# EIRE                      1
# Sweden                    1
# Canada                    1
# Iceland                   1

# %% [markdown]
# # Answer United Kingdom has the most VIP+Preferred Customers combined (177 + 755 = 872 Customers)
